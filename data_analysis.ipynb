# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import elephant
import viziphant
import neo
import pandas as pd
import quantities as pq
from elephant.statistics import isi

# %%
spkid = pd.read_csv('.\data\spkid.csv').to_numpy().flatten()
spkt = pd.read_csv('.\data\spktime.csv').to_numpy().flatten()

# %%
# import data as numpy array
st = neo.SpikeTrain(spkt, units= pq.ms, t_start=0, t_stop=1500)
st.annotations['spike_ids'] = spkid
# the times need to be the same fror each spk train t

# %%
plt.figure()
plt.plot(isi(st))
